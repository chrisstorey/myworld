# %%
import random
import pandas as pd

df = pd.read_csv('/home/chris/Personal_distro/myworld/appropriate_postcodes.csv')
df.head()
len(df)
# Out:
# 335762

# %%
df2 = df.sample(frac = 0.04)
df2.head()
len(df2)
# Out:
# 13430

# %%
df2.drop(columns=['Unnamed: 1'])
# Out:
#        Postcode
# 87900   HD9 6NE
# 118735  L26 9UU
# 197017  OL2 6NY
# 151208  LS279DJ
# 208941  PR4 0YF
# ...         ...
# 14197   BD108PA
# 225751  S36 6FU
# 314215  WN6 0YP
# 221425  S2  5JB
# 56625   DN158SN
#
# [13430 rows x 1 columns]

# %%
df2.to_csv('/home/chris/Personal_distro/myworld/appropriate_postcodes_sample.csv',index=False)

# %%
from faker import Faker
fake = Faker(locale='en-GB')
for _ in range(500):
    print(fake.name())
# Out:
# Billy Saunders
# Mrs. Jayne Williams
# Dr. Charlotte Gray
# Tracey Thomas
# Miss Kim Knight
# Abigail Davies-Jones
# Ms. Jane Gould
# Gail Armstrong
# Beverley West
# Dr. Rachel Pearce
# Mathew Rogers
# Mr. Douglas Begum
# Conor Burton
# Sara Barnes
# Mr. Martyn Doherty
# Pauline Lane-Johnson
# Alexandra Quinn
# Dr. Rachel Cook
# Robert Williams
# Dr. Alice Kaur
# Marie Ward-King
# Marian Mahmood
# Ms. Abbie Hudson
# Annette Davies
# Dr. Charlie Porter
# Leslie Clark
# Russell Harrison
# Hannah Roberts
# Lawrence Kirk
# Miss Chelsea Harris
# Dr. Jill Lewis
# Dr. Dylan Bailey
# Ryan Martin
# Katy Richardson-Farrell
# Sam Lee
# Dr. Jade Begum
# Paula White
# Ricky Roberts
# Dr. Howard Burns
# Gordon Akhtar
# Dr. Nathan Wilson
# Mrs. Leah Peters
# Kathleen Sims
# Lydia White
# Bernard Marshall
# Russell Powell
# Abdul Rogers
# Dr. Oliver Bartlett
# Ashley Rice
# Dr. Graeme Lambert
# Damien Ahmed
# James Parker
# Sam Dunn
# Julia Dawson
# Donna Robinson
# Lewis Harrison
# Shaun Green
# ...

# %%
import nationality.nat

# %%
for x in range(100):
    t=country_name()
    print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_533439/2358813918.py in <module>
#       1 for x in range(100):
# ----> 2     t=country_name()
#       3     print(t)
#       4
#       5
#
# NameError: name 'country_name' is not defined
